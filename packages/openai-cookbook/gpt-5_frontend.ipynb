# %%
import os
import re
import webbrowser
from pathlib import Path

import openai
from openai.types.responses import ResponseInputParam

client = openai.OpenAI()


def get_response_output_text(input: str | ResponseInputParam):
    
    response = client.responses.create(
        model="gpt-5",
        input=input,
    )
    return response.output_text


def extract_html_from_text(text: str):
    """Extract an HTML code block from text; fallback to first code block, else full text."""
    html_block = re.search(r"```html\s*(.*?)\s*```", text, re.DOTALL | re.IGNORECASE)
    if html_block:
        result = html_block.group(1)
        return result
    any_block = re.search(r"```\s*(.*?)\s*```", text, re.DOTALL)
    if any_block:
        result = any_block.group(1)
        return result
    return text


def save_html(html: str, filename: str) -> Path:
    """Save HTML to outputs/ directory and return the path."""
    try:
        base_dir = Path(__file__).parent
    except NameError:
        base_dir = Path.cwd()

    folder = "outputs"
    outputs_dir = base_dir / folder
    outputs_dir.mkdir(parents=True, exist_ok=True)

    output_path = outputs_dir / filename
    output_path.write_text(html, encoding="utf-8")
    return output_path

def open_in_browser(path: Path) -> None:
    """Open a file in the default browser (macOS compatible)."""
    try:
        webbrowser.open(path.as_uri())
    except Exception:
        os.system(f'open "{path}"')

# %%
def make_website_and_open_in_browser(*, website_input: str | ResponseInputParam, filename: str = "website.html"):
    response_text = get_response_output_text(website_input)
    html = extract_html_from_text(response_text)
    output_path = save_html(html, filename)
    open_in_browser(output_path)

# %%
make_website_and_open_in_browser(
    website_input="Make me landing page for a retro-games store. Retro-arcade noir some might say",
    filename="retro_dark.html",
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 make_website_and_open_in_browser(
#       2     website_input="Make me landing page for a retro-games store. Retro-arcade noir some might say",
#       3     filename="retro_dark.html",
#       4 )
#
# Cell In[8], line 2, in make_website_and_open_in_browser(website_input, filename)
#       1 def make_website_and_open_in_browser(*, website_input: str | ResponseInputParam, filename: str = "website.html"):
# ----> 2     response_text = get_response_output_text(website_input)
#       3     html = extract_html_from_text(response_text)
#       4     output_path = save_html(html, filename)
#
# Cell In[7], line 14, in get_response_output_text(input)
#      12 def get_response_output_text(input: str | ResponseInputParam):
# ---> 14     response = client.responses.create(
#      15         model="gpt-5",
#      16         input=input,
#      17     )
#      18     return response.output_text
#
# File ~/ai/.venv/lib/python3.13/site-packages/openai/resources/responses/responses.py:735, in Responses.create(self, background, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, reasoning, service_tier, store, stream, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     702 def create(
#     703     self,
#     704     *,
#    (...)    733     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     734 ) -> Response | Stream[ResponseStreamEvent]:
# --> 735     return self._post(
#     736         "/responses",
#     737         body=maybe_transform(
#     738             {
#     739                 "background": background,
#     740                 "include": include,
#     741                 "input": input,
#     742                 "instructions": instructions,
#     743                 "max_output_tokens": max_output_tokens,
#     744                 "max_tool_calls": max_tool_calls,
#     745                 "metadata": metadata,
#     746                 "model": model,
#     747                 "parallel_tool_calls": parallel_tool_calls,
#     748                 "previous_response_id": previous_response_id,
#     749                 "prompt": prompt,
#     750                 "reasoning": reasoning,
#     751                 "service_tier": service_tier,
#     752                 "store": store,
#     753                 "stream": stream,
#     754                 "temperature": temperature,
#     755                 "text": text,
#     756                 "tool_choice": tool_choice,
#     757                 "tools": tools,
#     758                 "top_logprobs": top_logprobs,
#     759                 "top_p": top_p,
#     760                 "truncation": truncation,
#     761                 "user": user,
#     762             },
#     763             response_create_params.ResponseCreateParamsStreaming
#     764             if stream
#     765             else response_create_params.ResponseCreateParamsNonStreaming,
#     766         ),
#     767         options=make_request_options(
#     768             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     769         ),
#     770         cast_to=Response,
#     771         stream=stream or False,
#     772         stream_cls=Stream[ResponseStreamEvent],
#     773     )
#
# File ~/ai/.venv/lib/python3.13/site-packages/openai/_base_client.py:1256, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1242 def post(
#    1243     self,
#    1244     path: str,
#    (...)   1251     stream_cls: type[_StreamT] | None = None,
#    1252 ) -> ResponseT | _StreamT:
#    1253     opts = FinalRequestOptions.construct(
#    1254         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1255     )
# -> 1256     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/ai/.venv/lib/python3.13/site-packages/openai/_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************ez4A. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
import openai

def check_openai_api_key(api_key):
    client = openai.OpenAI(api_key=api_key)
    try:
        client.models.list()
    except openai.AuthenticationError:
        return False
    else:
        return True


OPENAI_API_KEY = ""

if check_openai_api_key(OPENAI_API_KEY):
    print("Valid OpenAI API key.")
else:
    print("Invalid OpenAI API key.")
# Out:
# Invalid OpenAI API key.
